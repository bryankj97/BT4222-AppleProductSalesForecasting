# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating 4 Sentiment Features

# %%
tweets_bert = pd.read_csv('./data/tweets_bert.csv', index_col= 0).set_index('source')
tweets_countvect = pd.read_csv('./data/tweets_sentiment_countvect.csv', index_col= 0).set_index('source')
tweets_vader = pd.read_csv('./data/tweets_sentiment_vader.csv', index_col= 0).set_index('source')
tweets_tfidf = pd.read_csv('./data/tweets_tfidf.csv', index_col= 0).set_index('source')

# %%
sales = pd.read_csv('./data/sales.csv')
tweets = pd.read_csv('./data/tweets.csv', index_col= 0)

# %%
tweets = tweets.set_index('source')

# %%
tweets_bert['sentiment_bert'] = tweets_bert['sentiment']
tweets_bert['sentiment_tfidf'] = tweets_tfidf['sentiment']
tweets_bert['sentiment_vader'] = tweets_vader['sentiment']
tweets_bert['sentiment_countvect'] = tweets_countvect['sentiment']

# %%
tweets = tweets_bert[~tweets_bert['sentiment'].isna()].reset_index()

# %%
tweets_bert
# Out:
#                                                                                                   url  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...  https://twitter.com/lundp/status/1547135712536...
# <a href="http://twitter.com/download/iphone" re...  https://twitter.com/JayDCooke/status/154713564...
# <a href="http://twitter.com" rel="nofollow">Twi...  https://twitter.com/Semhar/status/154713498935...
# <a href="http://twitter.com" rel="nofollow">Twi...  https://twitter.com/JRizAnti_Tweets/status/154...
# <a href="http://www.cloudhopper.com/" rel="nofo...  https://twitter.com/laurengrumpy/status/154713...
# ...                                                                                               ...
# <a href="http://twitter.com/download/iphone" re...  https://twitter.com/peterdiseth/status/1080613...
# <a href="http://twitter.com" rel="nofollow">Twi...  https://twitter.com/SpeakingBee/status/1080613...
# <a href="http://twitter.com/download/iphone" re...  https://twitter.com/cubious/status/10806137853...
# <a href="http://twitter.com/download/android" r...  https://twitter.com/Zoli812/status/10806137796...
# <a href="https://about.twitter.com/products/twe...  https://twitter.com/ShiraOvide/status/10806137...
#
#                                                                          date  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...  2012-01-04 23:59:24+00:00
# <a href="http://twitter.com/download/iphone" re...  2012-01-04 23:59:22+00:00
# <a href="http://twitter.com" rel="nofollow">Twi...  2012-01-04 23:59:07+00:00
# <a href="http://twitter.com" rel="nofollow">Twi...  2012-01-04 23:59:04+00:00
# <a href="http://www.cloudhopper.com/" rel="nofo...  2012-01-04 23:58:50+00:00
# ...                                                                       ...
# <a href="http://twitter.com/download/iphone" re...  2019-01-02 23:56:28+00:00
# <a href="http://twitter.com" rel="nofollow">Twi...  2019-01-02 23:56:27+00:00
# <a href="http://twitter.com/download/iphone" re...  2019-01-02 23:56:17+00:00
# <a href="http://twitter.com/download/android" r...  2019-01-02 23:56:16+00:00
# <a href="https://about.twitter.com/products/twe...  2019-01-02 23:56:04+00:00
#
#                                                                                               content  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...  Trying new iSkin protector on MacBook Pro. And...
# <a href="http://twitter.com/download/iphone" re...                   I'm ready to get on the #MacBook
# <a href="http://twitter.com" rel="nofollow">Twi...  Syncing my entire life. All my personal & DAWN...
# <a href="http://twitter.com" rel="nofollow">Twi...  @MsSweetShay87 yup this year i asked 4 an audi...
# <a href="http://www.cloudhopper.com/" rel="nofo...  @comptonasswoo MacBook! I'm considering buying...
# ...                                                                                               ...
# <a href="http://twitter.com/download/iphone" re...  @riogreyhound If you have an iPhone, you go in...
# <a href="http://twitter.com" rel="nofollow">Twi...  @joshtpm @gruber I'd upgrade mine if Apple cou...
# <a href="http://twitter.com/download/iphone" re...  @paulmasonnews My iphone 4 is still beautiful ...
# <a href="http://twitter.com/download/android" r...  @CNBCnow @AppleSupport should have quit making...
# <a href="https://about.twitter.com/products/twe...  iPhone sales generate two-thirds of Apple's re...
#
#                                                                      id  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...   154713571253686272
# <a href="http://twitter.com/download/iphone" re...   154713564031090689
# <a href="http://twitter.com" rel="nofollow">Twi...   154713498935496704
# <a href="http://twitter.com" rel="nofollow">Twi...   154713487900291074
# <a href="http://www.cloudhopper.com/" rel="nofo...   154713429821751296
# ...                                                                 ...
# <a href="http://twitter.com/download/iphone" re...  1080613828214358016
# <a href="http://twitter.com" rel="nofollow">Twi...  1080613826624610305
# <a href="http://twitter.com/download/iphone" re...  1080613785327542272
# <a href="http://twitter.com/download/android" r...  1080613779690450950
# <a href="https://about.twitter.com/products/twe...  1080613727232237568
#
#                                                                                    user  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...            https://twitter.com/lundp
# <a href="http://twitter.com/download/iphone" re...        https://twitter.com/JayDCooke
# <a href="http://twitter.com" rel="nofollow">Twi...           https://twitter.com/Semhar
# <a href="http://twitter.com" rel="nofollow">Twi...  https://twitter.com/JRizAnti_Tweets
# <a href="http://www.cloudhopper.com/" rel="nofo...     https://twitter.com/laurengrumpy
# ...                                                                                 ...
# <a href="http://twitter.com/download/iphone" re...      https://twitter.com/peterdiseth
# <a href="http://twitter.com" rel="nofollow">Twi...      https://twitter.com/SpeakingBee
# <a href="http://twitter.com/download/iphone" re...          https://twitter.com/cubious
# <a href="http://twitter.com/download/android" r...          https://twitter.com/Zoli812
# <a href="https://about.twitter.com/products/twe...       https://twitter.com/ShiraOvide
#
#                                                    outlinks tcooutlinks  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...       []          []
# <a href="http://twitter.com/download/iphone" re...       []          []
# <a href="http://twitter.com" rel="nofollow">Twi...       []          []
# <a href="http://twitter.com" rel="nofollow">Twi...       []          []
# <a href="http://www.cloudhopper.com/" rel="nofo...       []          []
# ...                                                     ...         ...
# <a href="http://twitter.com/download/iphone" re...       []          []
# <a href="http://twitter.com" rel="nofollow">Twi...       []          []
# <a href="http://twitter.com/download/iphone" re...       []          []
# <a href="http://twitter.com/download/android" r...       []          []
# <a href="https://about.twitter.com/products/twe...       []          []
#
#                                                     replyCount  retweetCount  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...         0.0           0.0
# <a href="http://twitter.com/download/iphone" re...         0.0           0.0
# <a href="http://twitter.com" rel="nofollow">Twi...         0.0           0.0
# <a href="http://twitter.com" rel="nofollow">Twi...         2.0           0.0
# <a href="http://www.cloudhopper.com/" rel="nofo...         1.0           0.0
# ...                                                        ...           ...
# <a href="http://twitter.com/download/iphone" re...         1.0           0.0
# <a href="http://twitter.com" rel="nofollow">Twi...         1.0           0.0
# <a href="http://twitter.com/download/iphone" re...         0.0           0.0
# <a href="http://twitter.com/download/android" r...         0.0           0.0
# <a href="https://about.twitter.com/products/twe...         3.0           6.0
#
#                                                    likeCount  ... media  \
# source                                                        ...
# <a href="http://itunes.apple.com/us/app/twitter...         0  ...   NaN
# <a href="http://twitter.com/download/iphone" re...         0  ...   NaN
# <a href="http://twitter.com" rel="nofollow">Twi...         0  ...   NaN
# <a href="http://twitter.com" rel="nofollow">Twi...         0  ...   NaN
# <a href="http://www.cloudhopper.com/" rel="nofo...         0  ...   NaN
# ...                                                      ...  ...   ...
# <a href="http://twitter.com/download/iphone" re...         2  ...   NaN
# <a href="http://twitter.com" rel="nofollow">Twi...         2  ...   NaN
# <a href="http://twitter.com/download/iphone" re...         0  ...   NaN
# <a href="http://twitter.com/download/android" r...         1  ...   NaN
# <a href="https://about.twitter.com/products/twe...        31  ...   NaN
#
#                                                    retweetedTweet quotedTweet  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...            NaN         NaN
# <a href="http://twitter.com/download/iphone" re...            NaN         NaN
# <a href="http://twitter.com" rel="nofollow">Twi...            NaN         NaN
# <a href="http://twitter.com" rel="nofollow">Twi...            NaN         NaN
# <a href="http://www.cloudhopper.com/" rel="nofo...            NaN         NaN
# ...                                                           ...         ...
# <a href="http://twitter.com/download/iphone" re...            NaN         NaN
# <a href="http://twitter.com" rel="nofollow">Twi...            NaN         NaN
# <a href="http://twitter.com/download/iphone" re...            NaN         NaN
# <a href="http://twitter.com/download/android" r...            NaN         NaN
# <a href="https://about.twitter.com/products/twe...            NaN         NaN
#
#                                                                                        mentionedUsers  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...                                                NaN
# <a href="http://twitter.com/download/iphone" re...                                                NaN
# <a href="http://twitter.com" rel="nofollow">Twi...                                                NaN
# <a href="http://twitter.com" rel="nofollow">Twi...                                                NaN
# <a href="http://www.cloudhopper.com/" rel="nofo...  [User(username='Comptonasswoo', displayname='C...
# ...                                                                                               ...
# <a href="http://twitter.com/download/iphone" re...  [User(username='riogreyhound', displayname='Tr...
# <a href="http://twitter.com" rel="nofollow">Twi...  [User(username='joshtpm', displayname='Josh Ma...
# <a href="http://twitter.com/download/iphone" re...  [User(username='paulmasonnews', displayname='P...
# <a href="http://twitter.com/download/android" r...  [User(username='CNBCnow', displayname='CNBC No...
# <a href="https://about.twitter.com/products/twe...                                                NaN
#
#                                                     device sentiment  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...     mac      -1.0
# <a href="http://twitter.com/download/iphone" re...     mac       0.0
# <a href="http://twitter.com" rel="nofollow">Twi...     mac      -1.0
# <a href="http://twitter.com" rel="nofollow">Twi...     mac       0.0
# <a href="http://www.cloudhopper.com/" rel="nofo...     mac       0.0
# ...                                                    ...       ...
# <a href="http://twitter.com/download/iphone" re...  iphone       0.0
# <a href="http://twitter.com" rel="nofollow">Twi...  iphone       1.0
# <a href="http://twitter.com/download/iphone" re...  iphone       1.0
# <a href="http://twitter.com/download/android" r...  iphone      -1.0
# <a href="https://about.twitter.com/products/twe...  iphone       0.0
#
#                                                    sentiment_bert  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...           -1.0
# <a href="http://twitter.com/download/iphone" re...            0.0
# <a href="http://twitter.com" rel="nofollow">Twi...           -1.0
# <a href="http://twitter.com" rel="nofollow">Twi...            0.0
# <a href="http://www.cloudhopper.com/" rel="nofo...            0.0
# ...                                                           ...
# <a href="http://twitter.com/download/iphone" re...            0.0
# <a href="http://twitter.com" rel="nofollow">Twi...            1.0
# <a href="http://twitter.com/download/iphone" re...            1.0
# <a href="http://twitter.com/download/android" r...           -1.0
# <a href="https://about.twitter.com/products/twe...            0.0
#
#                                                     sentiment_tfidf  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...              0.0
# <a href="http://twitter.com/download/iphone" re...              0.0
# <a href="http://twitter.com" rel="nofollow">Twi...             -1.0
# <a href="http://twitter.com" rel="nofollow">Twi...              0.0
# <a href="http://www.cloudhopper.com/" rel="nofo...              0.0
# ...                                                             ...
# <a href="http://twitter.com/download/iphone" re...              0.0
# <a href="http://twitter.com" rel="nofollow">Twi...              0.0
# <a href="http://twitter.com/download/iphone" re...              1.0
# <a href="http://twitter.com/download/android" r...              0.0
# <a href="https://about.twitter.com/products/twe...              0.0
#
#                                                    sentiment_vader  \
# source
# <a href="http://itunes.apple.com/us/app/twitter...            -1.0
# <a href="http://twitter.com/download/iphone" re...             1.0
# <a href="http://twitter.com" rel="nofollow">Twi...            -1.0
# <a href="http://twitter.com" rel="nofollow">Twi...             1.0
# <a href="http://www.cloudhopper.com/" rel="nofo...             0.0
# ...                                                            ...
# <a href="http://twitter.com/download/iphone" re...             1.0
# <a href="http://twitter.com" rel="nofollow">Twi...             1.0
# <a href="http://twitter.com/download/iphone" re...             1.0
# <a href="http://twitter.com/download/android" r...            -1.0
# <a href="https://about.twitter.com/products/twe...             0.0
#
#                                                    sentiment_countvect
# source
# <a href="http://itunes.apple.com/us/app/twitter...                -1.0
# <a href="http://twitter.com/download/iphone" re...                 0.0
# <a href="http://twitter.com" rel="nofollow">Twi...                -1.0
# <a href="http://twitter.com" rel="nofollow">Twi...                -1.0
# <a href="http://www.cloudhopper.com/" rel="nofo...                 0.0
# ...                                                                ...
# <a href="http://twitter.com/download/iphone" re...                 0.0
# <a href="http://twitter.com" rel="nofollow">Twi...                 0.0
# <a href="http://twitter.com/download/iphone" re...                 1.0
# <a href="http://twitter.com/download/android" r...                 0.0
# <a href="https://about.twitter.com/products/twe...                 0.0
#
# [61450 rows x 25 columns]

# %% [markdown]
# ## Aggregating Features

# %%
sales['QTR_IDX'] = sales['Quarter'].apply(lambda x: str(20) + x[-2:] + "_" +  x[0])

# %%
sales['QTR_IDX']
# Out:
# 0     2012_1
# 1     2012_2
# 2     2012_3
# 3     2012_4
# 4     2013_1
# 5     2013_2
# 6     2013_3
# 7     2013_4
# 8     2014_1
# 9     2014_2
# 10    2014_3
# 11    2014_4
# 12    2015_1
# 13    2015_2
# 14    2015_3
# 15    2015_4
# 16    2016_1
# 17    2016_2
# 18    2016_3
# 19    2016_4
# 20    2017_1
# 21    2017_2
# 22    2017_3
# 23    2017_4
# 24    2018_1
# 25    2018_2
# 26    2018_3
# 27    2018_4
# Name: QTR_IDX, dtype: object

# %%
import datetime as dt
import numpy as n

tweets['date'] = pd.to_datetime(tweets['date'], format='%Y.%m.%d %H:%M:%S.%f')

# %%
tweets['year'] = tweets['date'].dt.year
tweets = tweets[tweets.year != 2019]

# %%
tweets['QTR_IDX'] = tweets['year'].astype('str').str.cat(tweets['date'].dt.quarter.astype(str), "_")

# %%
tweets.head()
# Out:
#                                               source  \
# 0  <a href="http://itunes.apple.com/us/app/twitte...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com" rel="nofollow">Tw...
# 3  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  <a href="http://www.cloudhopper.com/" rel="nof...
#
#                                                  url  \
# 0  https://twitter.com/lundp/status/1547135712536...
# 1  https://twitter.com/JayDCooke/status/154713564...
# 2  https://twitter.com/Semhar/status/154713498935...
# 3  https://twitter.com/JRizAnti_Tweets/status/154...
# 4  https://twitter.com/laurengrumpy/status/154713...
#
#                        date  \
# 0 2012-01-04 23:59:24+00:00
# 1 2012-01-04 23:59:22+00:00
# 2 2012-01-04 23:59:07+00:00
# 3 2012-01-04 23:59:04+00:00
# 4 2012-01-04 23:58:50+00:00
#
#                                              content                  id  \
# 0  Trying new iSkin protector on MacBook Pro. And...  154713571253686272
# 1                   I'm ready to get on the #MacBook  154713564031090689
# 2  Syncing my entire life. All my personal & DAWN...  154713498935496704
# 3  @MsSweetShay87 yup this year i asked 4 an audi...  154713487900291074
# 4  @comptonasswoo MacBook! I'm considering buying...  154713429821751296
#
#                                   user outlinks tcooutlinks  replyCount  \
# 0            https://twitter.com/lundp       []          []         0.0
# 1        https://twitter.com/JayDCooke       []          []         0.0
# 2           https://twitter.com/Semhar       []          []         0.0
# 3  https://twitter.com/JRizAnti_Tweets       []          []         2.0
# 4     https://twitter.com/laurengrumpy       []          []         1.0
#
#    retweetCount  ... quotedTweet  \
# 0           0.0  ...         NaN
# 1           0.0  ...         NaN
# 2           0.0  ...         NaN
# 3           0.0  ...         NaN
# 4           0.0  ...         NaN
#
#                                       mentionedUsers device sentiment  \
# 0                                                NaN    mac      -1.0
# 1                                                NaN    mac       0.0
# 2                                                NaN    mac      -1.0
# 3                                                NaN    mac       0.0
# 4  [User(username='Comptonasswoo', displayname='C...    mac       0.0
#
#   sentiment_bert sentiment_tfidf sentiment_vader sentiment_countvect  year  \
# 0           -1.0             0.0            -1.0                -1.0  2012
# 1            0.0             0.0             1.0                 0.0  2012
# 2           -1.0            -1.0            -1.0                -1.0  2012
# 3            0.0             0.0             1.0                -1.0  2012
# 4            0.0             0.0             0.0                 0.0  2012
#
#   QTR_IDX
# 0  2012_1
# 1  2012_1
# 2  2012_1
# 3  2012_1
# 4  2012_1
#
# [5 rows x 28 columns]

# %%
tweets.columns
# Out:
# Index(['source', 'url', 'date', 'content', 'id', 'user', 'outlinks',
#        'tcooutlinks', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'sourceUrl', 'sourceLabel', 'media',
#        'retweetedTweet', 'quotedTweet', 'mentionedUsers', 'device',
#        'sentiment', 'sentiment_bert', 'sentiment_tfidf', 'sentiment_vader',
#        'sentiment_countvect', 'year', 'QTR_IDX'],
#       dtype='object')

# %%
import numpy as np

# %%
df = tweets[['date', 'content', 'user', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount','QTR_IDX','device','sentiment_vader','sentiment_tfidf', 'sentiment_countvect', 'sentiment_bert']]
df.likeCount = df.likeCount.astype('float')
df.quoteCount = df.quoteCount.astype('float')


df_stats1 = df.groupby(['QTR_IDX', 'device']).sum()
df_stats2 = df.groupby(['QTR_IDX','device']).mean()
df_stats3 = df.groupby(['QTR_IDX','device']).user.count()

df_stats = df_stats1.merge(df_stats2, left_index=True, right_index=True, suffixes=('_sum', '_mean'))
#df_stats = df_stats.apply(lambda x: np.log(x) if x.max() >10 else x)
df_stats[df_stats<0] = 0
# Out:
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\pandas\core\generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_stats['count'] = df.groupby(['QTR_IDX','device']).user.count()
# Out:
#                 replyCount_sum  retweetCount_sum  likeCount_sum  \
# QTR_IDX device
# 2012_1  ipad             406.0              41.0           60.0
#         iphone           376.0             116.0           12.0
#         mac              330.0              33.0            8.0
# 2012_2  ipad             227.0              43.0           30.0
#         iphone           240.0              77.0           29.0
# ...                        ...               ...            ...
# 2018_3  iphone           435.0             192.0         3232.0
#         mac             1200.0             274.0         5655.0
# 2018_4  ipad             300.0              72.0         1242.0
#         iphone           404.0             166.0         1978.0
#         mac              436.0             517.0         2444.0
#
#                 quoteCount_sum  sentiment_vader_sum  sentiment_tfidf_sum  \
# QTR_IDX device
# 2012_1  ipad               0.0                190.0                  7.0
#         iphone             0.0                 55.0                  0.0
#         mac                0.0                234.0                  0.0
# 2012_2  ipad               0.0                198.0                  0.0
#         iphone             0.0                 86.0                  0.0
# ...                        ...                  ...                  ...
# 2018_3  iphone            45.0                117.0                  0.0
#         mac               74.0                118.0                  0.0
# 2018_4  ipad              24.0                208.0                  0.0
#         iphone            31.0                147.0                  0.0
#         mac               42.0                150.0                  0.0
#
#                 sentiment_countvect_sum  sentiment_bert_sum  replyCount_mean  \
# QTR_IDX device
# 2012_1  ipad                       24.0                31.0         0.563889
#         iphone                      0.0                 0.0         0.522222
#         mac                         0.0                48.0         0.458333
# 2012_2  ipad                       54.0                 9.0         0.315278
#         iphone                      0.0                 0.0         0.333333
# ...                                 ...                 ...              ...
# 2018_3  iphone                      0.0                 0.0         0.572368
#         mac                         0.0                 0.0         1.578947
# 2018_4  ipad                       34.0                63.0         0.416667
#         iphone                      0.0                 8.0         0.561111
#         mac                         0.0                 0.0         0.605556
#
#                 retweetCount_mean  likeCount_mean  quoteCount_mean  \
# QTR_IDX device
# 2012_1  ipad             0.056944        0.083333         0.000000
#         iphone           0.161111        0.016667         0.000000
#         mac              0.045833        0.011111         0.000000
# 2012_2  ipad             0.059722        0.041667         0.000000
#         iphone           0.106944        0.040278         0.000000
# ...                           ...             ...              ...
# 2018_3  iphone           0.252632        4.252632         0.059211
#         mac              0.360526        7.440789         0.097368
# 2018_4  ipad             0.100000        1.725000         0.033333
#         iphone           0.230556        2.747222         0.043056
#         mac              0.718056        3.394444         0.058333
#
#                 sentiment_vader_mean  sentiment_tfidf_mean  \
# QTR_IDX device
# 2012_1  ipad                0.263889              0.009722
#         iphone              0.076389              0.000000
#         mac                 0.325000              0.000000
# 2012_2  ipad                0.275000              0.000000
#         iphone              0.119444              0.000000
# ...                              ...                   ...
# 2018_3  iphone              0.153947              0.000000
#         mac                 0.155263              0.000000
# 2018_4  ipad                0.288889              0.000000
#         iphone              0.204167              0.000000
#         mac                 0.208333              0.000000
#
#                 sentiment_countvect_mean  sentiment_bert_mean  count
# QTR_IDX device
# 2012_1  ipad                    0.033333             0.043056    720
#         iphone                  0.000000             0.000000    720
#         mac                     0.000000             0.066667    720
# 2012_2  ipad                    0.075000             0.012500    720
#         iphone                  0.000000             0.000000    720
# ...                                  ...                  ...    ...
# 2018_3  iphone                  0.000000             0.000000    760
#         mac                     0.000000             0.000000    760
# 2018_4  ipad                    0.047222             0.087500    720
#         iphone                  0.000000             0.011111    720
#         mac                     0.000000             0.000000    720
#
# [84 rows x 17 columns]

# %%
abs(df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_vader'] == -1]['sentiment_vader'].sum()))
# Out:
# QTR_IDX  device
# 2012_1   ipad      132.0
#          iphone    191.0
#          mac       135.0
# 2012_2   ipad      140.0
#          iphone    194.0
#                    ...
# 2018_3   iphone    190.0
#          mac       203.0
# 2018_4   ipad      156.0
#          iphone    170.0
#          mac       176.0
# Length: 84, dtype: float64

# %%
df_stats['vader_pos_count'] = df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_vader'] == 1]['sentiment_vader'].sum())
df_stats['bert_pos_count'] = df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_bert'] == 1]['sentiment_bert'].sum())
df_stats['tfidf_pos_count'] = df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_tfidf'] == 1]['sentiment_tfidf'].sum())
df_stats['countvect_pos_count'] = df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_countvect'] == 1]['sentiment_countvect'].sum())


df_stats['vader_pos_perc'] = df_stats['vader_pos_count']/df_stats['count']
df_stats['bert_pos_perc'] = df_stats['bert_pos_count']/df_stats['count']
df_stats['tfidf_pos_perc'] = df_stats['tfidf_pos_count']/df_stats['count']
df_stats['countvect_pos_perc'] = df_stats['countvect_pos_count']/df_stats['count']

df_stats['vader_neg_count'] = abs(df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_vader'] == -1]['sentiment_vader'].sum()))
df_stats['bert_neg_count'] = abs(df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_bert'] == -1]['sentiment_bert'].sum()))
df_stats['tfidf_neg_count'] = abs(df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_tfidf'] == -1]['sentiment_tfidf'].sum()))
df_stats['countvect_neg_count'] = abs(df.groupby(['QTR_IDX','device']).apply(lambda x: x[x['sentiment_countvect'] == -1]['sentiment_countvect'].sum()))


df_stats['vader_neg_perc'] = df_stats['vader_neg_count']/df_stats['count']
df_stats['bert_neg_perc'] = df_stats['bert_neg_count']/df_stats['count']
df_stats['tfidf_neg_perc'] = df_stats['tfidf_neg_count']/df_stats['count']
df_stats['countvect_neg_perc'] = df_stats['countvect_neg_count']/df_stats['count']

# %%
tweets_agg_stats = df_stats
tweets_agg_stats
# Out:
#                 replyCount_sum  retweetCount_sum  likeCount_sum  \
# QTR_IDX device
# 2012_1  ipad             406.0              41.0           60.0
#         iphone           376.0             116.0           12.0
#         mac              330.0              33.0            8.0
# 2012_2  ipad             227.0              43.0           30.0
#         iphone           240.0              77.0           29.0
# ...                        ...               ...            ...
# 2018_3  iphone           435.0             192.0         3232.0
#         mac             1200.0             274.0         5655.0
# 2018_4  ipad             300.0              72.0         1242.0
#         iphone           404.0             166.0         1978.0
#         mac              436.0             517.0         2444.0
#
#                 quoteCount_sum  sentiment_vader_sum  sentiment_tfidf_sum  \
# QTR_IDX device
# 2012_1  ipad               0.0                190.0                  7.0
#         iphone             0.0                 55.0                  0.0
#         mac                0.0                234.0                  0.0
# 2012_2  ipad               0.0                198.0                  0.0
#         iphone             0.0                 86.0                  0.0
# ...                        ...                  ...                  ...
# 2018_3  iphone            45.0                117.0                  0.0
#         mac               74.0                118.0                  0.0
# 2018_4  ipad              24.0                208.0                  0.0
#         iphone            31.0                147.0                  0.0
#         mac               42.0                150.0                  0.0
#
#                 sentiment_countvect_sum  sentiment_bert_sum  replyCount_mean  \
# QTR_IDX device
# 2012_1  ipad                       24.0                31.0         0.563889
#         iphone                      0.0                 0.0         0.522222
#         mac                         0.0                48.0         0.458333
# 2012_2  ipad                       54.0                 9.0         0.315278
#         iphone                      0.0                 0.0         0.333333
# ...                                 ...                 ...              ...
# 2018_3  iphone                      0.0                 0.0         0.572368
#         mac                         0.0                 0.0         1.578947
# 2018_4  ipad                       34.0                63.0         0.416667
#         iphone                      0.0                 8.0         0.561111
#         mac                         0.0                 0.0         0.605556
#
#                 retweetCount_mean  ...  tfidf_pos_perc  countvect_pos_perc  \
# QTR_IDX device                     ...
# 2012_1  ipad             0.056944  ...        0.176389            0.186111
#         iphone           0.161111  ...        0.168056            0.138889
#         mac              0.045833  ...        0.179167            0.212500
# 2012_2  ipad             0.059722  ...        0.186111            0.202778
#         iphone           0.106944  ...        0.159722            0.141667
# ...                           ...  ...             ...                 ...
# 2018_3  iphone           0.252632  ...        0.151316            0.172368
#         mac              0.360526  ...        0.130263            0.171053
# 2018_4  ipad             0.100000  ...        0.172222            0.212500
#         iphone           0.230556  ...        0.175000            0.169444
#         mac              0.718056  ...        0.145833            0.179167
#
#                 vader_neg_count  bert_neg_count  tfidf_neg_count  \
# QTR_IDX device
# 2012_1  ipad              132.0           119.0            120.0
#         iphone            191.0           171.0            153.0
#         mac               135.0           125.0            135.0
# 2012_2  ipad              140.0           129.0            138.0
#         iphone            194.0           162.0            170.0
# ...                         ...             ...              ...
# 2018_3  iphone            190.0           184.0            187.0
#         mac               203.0           177.0            201.0
# 2018_4  ipad              156.0           135.0            163.0
#         iphone            170.0           145.0            172.0
#         mac               176.0           186.0            185.0
#
#                 countvect_neg_count  vader_neg_perc  bert_neg_perc  \
# QTR_IDX device
# 2012_1  ipad                  110.0        0.183333       0.165278
#         iphone                112.0        0.265278       0.237500
#         mac                   222.0        0.187500       0.173611
# 2012_2  ipad                   92.0        0.194444       0.179167
#         iphone                122.0        0.269444       0.225000
# ...                             ...             ...            ...
# 2018_3  iphone                139.0        0.250000       0.242105
#         mac                   292.0        0.267105       0.232895
# 2018_4  ipad                  119.0        0.216667       0.187500
#         iphone                122.0        0.236111       0.201389
#         mac                   283.0        0.244444       0.258333
#
#                 tfidf_neg_perc  countvect_neg_perc
# QTR_IDX device
# 2012_1  ipad          0.166667            0.152778
#         iphone        0.212500            0.155556
#         mac           0.187500            0.308333
# 2012_2  ipad          0.191667            0.127778
#         iphone        0.236111            0.169444
# ...                        ...                 ...
# 2018_3  iphone        0.246053            0.182895
#         mac           0.264474            0.384211
# 2018_4  ipad          0.226389            0.165278
#         iphone        0.238889            0.169444
#         mac           0.256944            0.393056
#
# [84 rows x 33 columns]

# %%
tweets_agg_stats.columns
# Out:
# Index(['replyCount_sum', 'retweetCount_sum', 'likeCount_sum', 'quoteCount_sum',
#        'sentiment_vader_sum', 'sentiment_tfidf_sum', 'sentiment_countvect_sum',
#        'sentiment_bert_sum', 'replyCount_mean', 'retweetCount_mean',
#        'likeCount_mean', 'quoteCount_mean', 'sentiment_vader_mean',
#        'sentiment_tfidf_mean', 'sentiment_countvect_mean',
#        'sentiment_bert_mean', 'count', 'vader_pos_count', 'bert_pos_count',
#        'tfidf_pos_count', 'countvect_pos_count', 'vader_pos_perc',
#        'bert_pos_perc', 'tfidf_pos_perc', 'countvect_pos_perc',
#        'vader_neg_count', 'bert_neg_count', 'tfidf_neg_count',
#        'countvect_neg_count', 'vader_neg_perc', 'bert_neg_perc',
#        'tfidf_neg_perc', 'countvect_neg_perc'],
#       dtype='object')

# %%
sales_long = pd.DataFrame()
for d in ['iPhone*', 'iPad*', 'Mac*']:
    sales_long = pd.concat([sales_long, pd.DataFrame({"sales":sales[d], "device": d[:-1].lower(),"QTR_IDX_SALES" : sales['QTR_IDX'], 'QTR_IDX_PREV': sales['QTR_IDX'].shift(1)})])

# %%
sales_long
# Out:
#     sales  device QTR_IDX_SALES QTR_IDX_PREV
# 0   37.04  iphone        2012_1          NaN
# 1   35.06  iphone        2012_2       2012_1
# 2   26.03  iphone        2012_3       2012_2
# 3   26.91  iphone        2012_4       2012_3
# 4   47.79  iphone        2013_1       2012_4
# ..    ...     ...           ...          ...
# 23   5.39     mac        2017_4       2017_3
# 24   5.11     mac        2018_1       2017_4
# 25   4.08     mac        2018_2       2018_1
# 26   3.72     mac        2018_3       2018_2
# 27   5.30     mac        2018_4       2018_3
#
# [84 rows x 4 columns]

# %% [markdown]
# ## Merge to Sales Data

# %%
sales_long.merge(tweets_agg_stats, left_on= ('QTR_IDX_PREV','device'), right_on = ('QTR_IDX','device')).to_csv('./data/sales_tweets.csv')

# %%
sales_tweets = pd.read_csv('./data/sales_tweets.csv', index_col=0)

# %%
sales_tweets
# Out:
#     sales  device QTR_IDX_SALES QTR_IDX_PREV  replyCount_sum  \
# 0   35.06  iphone        2012_2       2012_1           376.0
# 1   26.03  iphone        2012_3       2012_2           240.0
# 2   26.91  iphone        2012_4       2012_3           263.0
# 3   47.79  iphone        2013_1       2012_4           266.0
# 4   37.43  iphone        2013_2       2013_1           218.0
# ..    ...     ...           ...          ...             ...
# 76   5.39     mac        2017_4       2017_3           371.0
# 77   5.11     mac        2018_1       2017_4           420.0
# 78   4.08     mac        2018_2       2018_1           443.0
# 79   3.72     mac        2018_3       2018_2           399.0
# 80   5.30     mac        2018_4       2018_3          1200.0
#
#     retweetCount_sum  likeCount_sum  quoteCount_sum  sentiment_vader_sum  \
# 0              116.0           12.0             0.0                 55.0
# 1               77.0           29.0             0.0                 86.0
# 2              154.0          137.0             0.0                 66.0
# 3              131.0          116.0             0.0                 48.0
# 4              132.0          137.0             0.0                 71.0
# ..               ...            ...             ...                  ...
# 76              73.0         1069.0            25.0                120.0
# 77              98.0         1420.0            40.0                102.0
# 78              73.0         1065.0            31.0                179.0
# 79             116.0         1210.0            35.0                106.0
# 80             274.0         5655.0            74.0                118.0
#
#     sentiment_tfidf_sum  ...  bert_neg_count  tfidf_neg_count  \
# 0                   0.0  ...           171.0            153.0
# 1                   0.0  ...           162.0            170.0
# 2                   0.0  ...           187.0            193.0
# 3                   0.0  ...           183.0            172.0
# 4                   0.0  ...           172.0            184.0
# ..                  ...  ...             ...              ...
# 76                  0.0  ...           165.0            189.0
# 77                  0.0  ...           183.0            185.0
# 78                  0.0  ...           189.0            209.0
# 79                  0.0  ...           209.0            211.0
# 80                  0.0  ...           177.0            201.0
#
#     countvect_neg_count  vader_neg_perc  bert_neg_perc  tfidf_neg_perc  \
# 0                 112.0        0.265278       0.237500        0.212500
# 1                 122.0        0.269444       0.225000        0.236111
# 2                 140.0        0.268421       0.246053        0.253947
# 3                 122.0        0.265278       0.254167        0.238889
# 4                 113.0        0.250000       0.238889        0.255556
# ..                  ...             ...            ...             ...
# 76                266.0        0.226316       0.217105        0.248684
# 77                251.0        0.254167       0.254167        0.256944
# 78                295.0        0.219444       0.262500        0.290278
# 79                288.0        0.295833       0.290278        0.293056
# 80                292.0        0.267105       0.232895        0.264474
#
#     countvect_neg_perc  iphone  ipad  sales_norm
# 0             0.155556       1     0   -0.860530
# 1             0.169444       1     0   -1.480431
# 2             0.184211       1     0   -1.420020
# 3             0.169444       1     0    0.013374
# 4             0.156944       1     0   -0.697831
# ..                 ...     ...   ...         ...
# 76            0.350000       0     0    1.256227
# 77            0.348611       0     0    0.799637
# 78            0.409722       0     0   -0.879963
# 79            0.400000       0     0   -1.467007
# 80            0.384211       0     0    1.109465
#
# [81 rows x 40 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
sales_tweets['iphone'] = np.where(sales_tweets['device'] == 'iphone',1,0)
sales_tweets['ipad'] = np.where(sales_tweets['device'] == 'ipad',1,0)

# %% [markdown]
# ## Simple Linear Regression using aggregated metrics - without normalizing

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets.set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets.set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales', 'sales_norm'], axis=1), train['sales']
X_test, y_test = test.drop(['sales', 'sales_norm'], axis=1), test['sales']

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train,X_train)

# %%
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  sales   R-squared (uncentered):                   0.962
# Model:                            OLS   Adj. R-squared (uncentered):              0.915
# Method:                 Least Squares   F-statistic:                              20.69
# Date:                Sun, 28 Mar 2021   Prob (F-statistic):                    2.87e-12
# Time:                        22:54:59   Log-Likelihood:                         -190.48
# No. Observations:                  60   AIC:                                      447.0
# Df Residuals:                      27   BIC:                                      516.1
# Df Model:                          33
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# replyCount_sum              -4.3861      5.818     -0.754      0.457     -16.324       7.551
# retweetCount_sum             0.2505      2.036      0.123      0.903      -3.926       4.427
# likeCount_sum               -0.2928      0.652     -0.449      0.657      -1.631       1.046
# quoteCount_sum              20.9552     34.621      0.605      0.550     -50.080      91.991
# sentiment_vader_sum          6.0233     14.633      0.412      0.684     -24.000      36.047
# sentiment_tfidf_sum       -108.1884    306.210     -0.353      0.727    -736.479     520.102
# sentiment_countvect_sum     14.0198    187.259      0.075      0.941    -370.205     398.244
# sentiment_bert_sum          24.7210     31.208      0.792      0.435     -39.312      88.754
# replyCount_mean           3108.7791   4193.429      0.741      0.465   -5495.426    1.17e+04
# retweetCount_mean         -187.2507   1468.548     -0.128      0.899   -3200.463    2825.961
# likeCount_mean             228.3717    471.832      0.484      0.632    -739.748    1196.492
# quoteCount_mean          -1.509e+04   2.49e+04     -0.605      0.550   -6.63e+04    3.61e+04
# sentiment_vader_mean     -4328.2403   1.05e+04     -0.411      0.685    -2.6e+04    1.73e+04
# sentiment_tfidf_mean      7.864e+04   2.21e+05      0.356      0.724   -3.74e+05    5.32e+05
# sentiment_countvect_mean -9735.8704   1.35e+05     -0.072      0.943   -2.86e+05    2.67e+05
# sentiment_bert_mean      -1.757e+04   2.25e+04     -0.781      0.442   -6.37e+04    2.86e+04
# count                       -0.0521      0.065     -0.797      0.432      -0.186       0.082
# vader_pos_count             -3.9737     15.805     -0.251      0.803     -36.403      28.456
# bert_pos_count             -48.6092     45.213     -1.075      0.292    -141.378      44.159
# tfidf_pos_count              0.7136     30.497      0.023      0.982     -61.862      63.289
# countvect_pos_count         39.6401     29.069      1.364      0.184     -20.004      99.285
# vader_pos_perc            2779.5243   1.14e+04      0.244      0.809   -2.06e+04    2.61e+04
# bert_pos_perc             3.525e+04   3.26e+04      1.082      0.289   -3.16e+04    1.02e+05
# tfidf_pos_perc            -315.6166    2.2e+04     -0.014      0.989   -4.54e+04    4.48e+04
# countvect_pos_perc       -2.869e+04    2.1e+04     -1.368      0.183   -7.17e+04    1.43e+04
# vader_neg_count             -9.9968     29.928     -0.334      0.741     -71.404      51.410
# bert_neg_count              10.7564     60.039      0.179      0.859    -112.434     133.947
# tfidf_neg_count             20.1364     20.050      1.004      0.324     -21.003      61.276
# countvect_neg_count         -1.7196      6.748     -0.255      0.801     -15.565      12.126
# vader_neg_perc            7107.7645   2.16e+04      0.330      0.744   -3.71e+04    5.13e+04
# bert_neg_perc            -7574.3674   4.32e+04     -0.175      0.862   -9.63e+04    8.11e+04
# tfidf_neg_perc           -1.445e+04   1.44e+04     -1.001      0.326   -4.41e+04    1.52e+04
# countvect_neg_perc        1244.3331   4878.986      0.255      0.801   -8766.519    1.13e+04
# iphone                      41.9632     24.161      1.737      0.094      -7.611      91.538
# ipad                         1.9811     17.054      0.116      0.908     -33.011      36.973
# ==============================================================================
# Omnibus:                        9.252   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               12.971
# Skew:                           0.514   Prob(JB):                      0.00153
# Kurtosis:                       5.032   Cond. No.                     1.06e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.01e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
plt.style.use('ggplot')
plt.plot(y_test)
plt.plot(results.predict(X_test))
plt.legend(['Actual Sales', 'Prediction'])

# %%
from sklearn.metrics import mean_squared_error as mse

mse(y_test, results.predict(X_test),squared=False)
# Out:
# 51.038168788340855

# %% [markdown]
# ### iPhone

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets[sales_tweets['iphone']==1].set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets[sales_tweets['iphone']==1].set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales', 'sales_norm'], axis=1), train['sales']
X_test, y_test = test.drop(['sales', 'sales_norm'], axis=1), test['sales']

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()
results.summary()
# Out:
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\statsmodels\regression\linear_model.py:1830: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     2.701
# Date:                Sun, 28 Mar 2021   Prob (F-statistic):              0.304
# Time:                        23:03:15   Log-Likelihood:                -50.758
# No. Observations:                  20   AIC:                             137.5
# Df Residuals:                       2   BIC:                             155.4
# Df Model:                          17
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# replyCount_sum        -1.4576     13.131     -0.111      0.922     -57.954      55.038
# retweetCount_sum       4.2522      3.177      1.338      0.313      -9.418      17.923
# likeCount_sum         -0.0450      3.197     -0.014      0.990     -13.801      13.711
# quoteCount_sum       -73.7463    266.995     -0.276      0.808   -1222.535    1075.042
# replyCount_mean     1067.8404   9469.029      0.113      0.921   -3.97e+04    4.18e+04
# retweetCount_mean  -3241.8417   2299.295     -1.410      0.294   -1.31e+04    6651.225
# likeCount_mean        99.1745   2300.396      0.043      0.970   -9798.631    9996.980
# quoteCount_mean     5.292e+04   1.92e+05      0.275      0.809   -7.75e+05    8.81e+05
# count                 -0.5844      4.742     -0.123      0.913     -20.987      19.819
# vader_pos_perc        86.6054    194.109      0.446      0.699    -748.578     921.789
# bert_pos_perc        339.3626    410.215      0.827      0.495   -1425.649    2104.374
# tfidf_pos_perc      -233.9650    517.577     -0.452      0.696   -2460.920    1992.990
# countvect_pos_perc  -147.3216    597.041     -0.247      0.828   -2716.180    2421.537
# vader_neg_perc      -428.3609    293.481     -1.460      0.282   -1691.108     834.386
# bert_neg_perc        773.8346    544.267      1.422      0.291   -1567.956    3115.625
# tfidf_neg_perc       -52.9026    352.859     -0.150      0.895   -1571.132    1465.326
# countvect_neg_perc  -241.8459    423.612     -0.571      0.626   -2064.500    1580.808
# iphone               421.0314   3395.121      0.124      0.913   -1.42e+04     1.5e+04
# ipad                        0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        8.211   Durbin-Watson:                   2.352
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                7.963
# Skew:                          -0.579   Prob(JB):                       0.0187
# Kurtosis:                       5.866   Cond. No.                          inf
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
plt.plot(y_test)
plt.plot(results.predict(X_test))

print("RMSE:", mse(y_test, results.predict(X_test),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()
# Out:
# RMSE: 209.35888814128637

# %% [markdown]
# ### iPad

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets[sales_tweets['ipad']==1].set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets[sales_tweets['ipad']==1].set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales', 'sales_norm'], axis=1), train['sales']
X_test, y_test = test.drop(['sales', 'sales_norm'], axis=1), test['sales']

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()
results.summary()
# Out:
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     10.26
# Date:                Sun, 28 Mar 2021   Prob (F-statistic):             0.0924
# Time:                        23:03:19   Log-Likelihood:                -13.702
# No. Observations:                  20   AIC:                             63.40
# Df Residuals:                       2   BIC:                             81.33
# Df Model:                          17
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# replyCount_sum        -3.7579      1.347     -2.789      0.108      -9.555       2.039
# retweetCount_sum      -3.4940      0.524     -6.668      0.022      -5.749      -1.239
# likeCount_sum         -0.0815      0.102     -0.797      0.509      -0.521       0.358
# quoteCount_sum        -3.2123     10.421     -0.308      0.787     -48.052      41.628
# replyCount_mean     2741.0088    979.989      2.797      0.108   -1475.544    6957.561
# retweetCount_mean   2551.5915    380.424      6.707      0.022     914.757    4188.425
# likeCount_mean        67.1807     75.732      0.887      0.469    -258.666     393.027
# quoteCount_mean     2355.1312   7621.850      0.309      0.787   -3.04e+04    3.51e+04
# count                  1.7619      0.463      3.805      0.063      -0.231       3.754
# vader_pos_perc       199.3507     38.268      5.209      0.035      34.698     364.003
# bert_pos_perc         73.5933     60.670      1.213      0.349    -187.449     334.636
# tfidf_pos_perc         3.3747    118.640      0.028      0.980    -507.092     513.842
# countvect_pos_perc   164.8716    161.118      1.023      0.414    -528.363     858.106
# vader_neg_perc       161.7017     66.843      2.419      0.137    -125.900     449.304
# bert_neg_perc        -86.4287    111.763     -0.773      0.520    -567.308     394.451
# tfidf_neg_perc       207.2314     62.466      3.317      0.080     -61.539     476.002
# countvect_neg_perc  -120.9065     49.541     -2.441      0.135    -334.066      92.253
# iphone                      0          0        nan        nan           0           0
# ipad               -1446.4714    361.886     -3.997      0.057   -3003.541     110.598
# ==============================================================================
# Omnibus:                        8.305   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                5.786
# Skew:                           1.231   Prob(JB):                       0.0554
# Kurtosis:                       3.938   Cond. No.                     8.55e+23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.04e-41. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
plt.plot(y_train)
plt.plot(results.predict(X_train))

print("RMSE:", mse(y_train, results.predict(X_train),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()
# Out:
# RMSE: 0.4800689860930165

# %%
plt.plot(y_test)
plt.plot(results.predict(X_test))

print("RMSE:", mse(y_test, results.predict(X_test),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()
# Out:
# RMSE: 37.6676301112014

# %% [markdown]
# ### Mac

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets[(sales_tweets['ipad']==0) & (sales_tweets['iphone']==0)].set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets[(sales_tweets['ipad']==0) & (sales_tweets['iphone']==0)].set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales', 'sales_norm'], axis=1), train['sales']
X_test, y_test = test.drop(['sales', 'sales_norm'], axis=1), test['sales']

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()
results.summary()
# Out:
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.872
# Model:                            OLS   Adj. R-squared:                 -1.429
# Method:                 Least Squares   F-statistic:                    0.3790
# Date:                Sun, 28 Mar 2021   Prob (F-statistic):              0.878
# Time:                        22:55:46   Log-Likelihood:                 2.5586
# No. Observations:                  20   AIC:                             32.88
# Df Residuals:                       1   BIC:                             51.80
# Df Model:                          18
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# replyCount_sum               0.0543      1.389      0.039      0.975     -17.590      17.698
# retweetCount_sum            -0.0968      1.016     -0.095      0.940     -13.010      12.817
# likeCount_sum               -0.0044      0.141     -0.031      0.980      -1.798       1.789
# quoteCount_sum              -0.0795      0.501     -0.158      0.900      -6.452       6.293
# sentiment_vader_sum         -0.1662      0.591     -0.281      0.826      -7.679       7.346
# sentiment_tfidf_sum      -8.088e-10   9.88e-09     -0.082      0.948   -1.26e-07    1.25e-07
# sentiment_countvect_sum   1.003e-10   2.76e-09      0.036      0.977   -3.49e-08    3.51e-08
# sentiment_bert_sum           0.0008      0.562      0.001      0.999      -7.143       7.145
# replyCount_mean            -39.3086    994.065     -0.040      0.975   -1.27e+04    1.26e+04
# retweetCount_mean           69.3682    729.454      0.095      0.940   -9199.223    9337.959
# likeCount_mean               4.3030    106.339      0.040      0.974   -1346.858    1355.464
# quoteCount_mean             71.3005    385.016      0.185      0.883   -4820.795    4963.396
# sentiment_vader_mean       110.7960    436.216      0.254      0.842   -5431.856    5653.448
# sentiment_tfidf_mean      2.408e-10   3.23e-09      0.075      0.953   -4.08e-08    4.12e-08
# sentiment_countvect_mean  4.477e-13   8.16e-12      0.055      0.965   -1.03e-10    1.04e-10
# sentiment_bert_mean         22.0851    439.233      0.050      0.968   -5558.898    5603.068
# count                        0.0043      0.118      0.036      0.977      -1.495       1.504
# vader_pos_count             -0.0743      0.575     -0.129      0.918      -7.386       7.238
# bert_pos_count              -0.0848      0.251     -0.338      0.793      -3.273       3.103
# tfidf_pos_count              0.0711      0.526      0.135      0.915      -6.615       6.757
# countvect_pos_count          0.0551      0.555      0.099      0.937      -6.997       7.108
# vader_pos_perc              56.8026    324.715      0.175      0.890   -4069.092    4182.697
# bert_pos_perc               44.5290    254.832      0.175      0.890   -3193.414    3282.472
# tfidf_pos_perc             -46.6162    379.063     -0.123      0.922   -4863.068    4769.836
# countvect_pos_perc         -23.2297    202.823     -0.115      0.927   -2600.338    2553.878
# vader_neg_count              0.0919      0.591      0.155      0.902      -7.421       7.605
# bert_neg_count               0.0464      0.404      0.115      0.927      -5.084       5.177
# tfidf_neg_count             -0.0148      0.770     -0.019      0.988      -9.793       9.763
# countvect_neg_count          0.0811      0.339      0.239      0.850      -4.224       4.386
# vader_neg_perc             -53.9934    329.088     -0.164      0.896   -4235.447    4127.460
# bert_neg_perc              -43.4460    314.006     -0.138      0.912   -4033.266    3946.374
# tfidf_neg_perc               8.2782    495.507      0.017      0.989   -6287.737    6304.293
# countvect_neg_perc         -56.9409    243.524     -0.234      0.854   -3151.209    3037.327
# iphone                            0          0        nan        nan           0           0
# ipad                              0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        0.509   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.775   Jarque-Bera (JB):                0.011
# Skew:                           0.039   Prob(JB):                        0.994
# Kurtosis:                       3.086   Cond. No.                     4.39e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 1.13e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
plt.plot(y_test)
plt.plot(results.predict(X_test))

print("RMSE:", mse(y_test, results.predict(X_test),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()
# Out:
# RMSE: 4.5540864418549845

# %% [markdown]
# ## Simple Linear Regression using aggregated metrics - with normalizing SALES

# %%
sales_tweets['sales_norm'] = sales_tweets.groupby('device').sales.transform(lambda x: (x - x.mean()) / x.std())

# %%
sales_tweets.columns
# Out:
# Index(['sales', 'device', 'QTR_IDX_SALES', 'QTR_IDX_PREV', 'replyCount_sum',
#        'retweetCount_sum', 'likeCount_sum', 'quoteCount_sum',
#        'sentiment_vader_sum', 'sentiment_tfidf_sum', 'sentiment_countvect_sum',
#        'sentiment_bert_sum', 'replyCount_mean', 'retweetCount_mean',
#        'likeCount_mean', 'quoteCount_mean', 'sentiment_vader_mean',
#        'sentiment_tfidf_mean', 'sentiment_countvect_mean',
#        'sentiment_bert_mean', 'count', 'vader_pos_count', 'bert_pos_count',
#        'tfidf_pos_count', 'countvect_pos_count', 'vader_pos_perc',
#        'bert_pos_perc', 'tfidf_pos_perc', 'countvect_pos_perc',
#        'vader_neg_count', 'bert_neg_count', 'tfidf_neg_count',
#        'countvect_neg_count', 'vader_neg_perc', 'bert_neg_perc',
#        'tfidf_neg_perc', 'countvect_neg_perc', 'iphone', 'ipad', 'sales_norm'],
#       dtype='object')

# %%
sales_tweets = sales_tweets[['sales', 'device', 'QTR_IDX_SALES', 'QTR_IDX_PREV', 'replyCount_sum',
       'retweetCount_sum', 'likeCount_sum', 'quoteCount_sum',
       'replyCount_mean', 'retweetCount_mean',
       'likeCount_mean', 'quoteCount_mean', 'count', 'vader_pos_perc',
       'bert_pos_perc', 'tfidf_pos_perc', 'countvect_pos_perc','vader_neg_perc', 'bert_neg_perc',
       'tfidf_neg_perc', 'countvect_neg_perc', 'iphone', 'ipad', 'sales_norm']]

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets[sales_tweets['ipad']==1].set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets[sales_tweets['ipad']==1].set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales','sales_norm'], axis=1), train['sales_norm']
X_test, y_test = test.drop(['sales','sales_norm'], axis=1), test['sales_norm']

# %%
X_train
# Out:
#                replyCount_sum  retweetCount_sum  likeCount_sum  \
# QTR_IDX_SALES
# 2012_2                  406.0              41.0           60.0
# 2012_3                  227.0              43.0           30.0
# 2012_4                  266.0             103.0           48.0
# 2013_1                  190.0              97.0           61.0
# 2013_2                  211.0             185.0          199.0
# 2013_3                  192.0              64.0          107.0
# 2013_4                  217.0              74.0          233.0
# 2014_1                  215.0             265.0          289.0
# 2014_2                  187.0              75.0          220.0
# 2014_3                  169.0             408.0          308.0
# 2014_4                  150.0             468.0          308.0
# 2015_1                  179.0             372.0          396.0
# 2015_2                  230.0             192.0          399.0
# 2015_3                  231.0              99.0          494.0
# 2015_4                  243.0             171.0          826.0
# 2016_1                  227.0              50.0          349.0
# 2016_2                  240.0              74.0          540.0
# 2016_3                  232.0              59.0          649.0
# 2016_4                  261.0              65.0          591.0
# 2017_1                  251.0             111.0          949.0
#
#                quoteCount_sum  replyCount_mean  retweetCount_mean  \
# QTR_IDX_SALES
# 2012_2                    0.0         0.563889           0.056944
# 2012_3                    0.0         0.315278           0.059722
# 2012_4                    0.0         0.350000           0.135526
# 2013_1                    0.0         0.263889           0.134722
# 2013_2                    0.0         0.293463           0.257302
# 2013_3                    0.0         0.266667           0.088889
# 2013_4                    0.0         0.285526           0.097368
# 2014_1                    0.0         0.298611           0.368056
# 2014_2                    0.0         0.259722           0.104167
# 2014_3                    0.0         0.234722           0.566667
# 2014_4                    1.0         0.197368           0.615789
# 2015_1                    0.0         0.248957           0.517385
# 2015_2                    1.0         0.319444           0.266667
# 2015_3                    0.0         0.320833           0.137500
# 2015_4                    0.0         0.319737           0.225000
# 2016_1                    0.0         0.315278           0.069444
# 2016_2                    0.0         0.333333           0.102778
# 2016_3                    3.0         0.322222           0.081944
# 2016_4                   10.0         0.343421           0.085526
# 2017_1                   31.0         0.348611           0.154167
#
#                likeCount_mean  quoteCount_mean  count  vader_pos_perc  \
# QTR_IDX_SALES
# 2012_2               0.083333         0.000000    720        0.447222
# 2012_3               0.041667         0.000000    720        0.469444
# 2012_4               0.063158         0.000000    760        0.459211
# 2013_1               0.084722         0.000000    720        0.443056
# 2013_2               0.276773         0.000000    719        0.433936
# 2013_3               0.148611         0.000000    720        0.400000
# 2013_4               0.306579         0.000000    760        0.388158
# 2014_1               0.401389         0.000000    720        0.419444
# 2014_2               0.305556         0.000000    720        0.434722
# 2014_3               0.427778         0.000000    720        0.369444
# 2014_4               0.405263         0.001316    760        0.482895
# 2015_1               0.550765         0.000000    719        0.456189
# 2015_2               0.554167         0.001389    720        0.393056
# 2015_3               0.686111         0.000000    720        0.401389
# 2015_4               1.086842         0.000000    760        0.407895
# 2016_1               0.484722         0.000000    720        0.423611
# 2016_2               0.750000         0.000000    720        0.387500
# 2016_3               0.901389         0.004167    720        0.409722
# 2016_4               0.777632         0.013158    760        0.398684
# 2017_1               1.318056         0.043056    720        0.409722
#
#                bert_pos_perc  tfidf_pos_perc  countvect_pos_perc  \
# QTR_IDX_SALES
# 2012_2              0.208333        0.176389            0.186111
# 2012_3              0.191667        0.186111            0.202778
# 2012_4              0.223684        0.190789            0.202632
# 2013_1              0.222222        0.186111            0.205556
# 2013_2              0.215577        0.189152            0.197497
# 2013_3              0.206944        0.204167            0.216667
# 2013_4              0.184211        0.169737            0.171053
# 2014_1              0.220833        0.183333            0.193056
# 2014_2              0.245833        0.163889            0.172222
# 2014_3              0.202778        0.154167            0.169444
# 2014_4              0.313158        0.272368            0.276316
# 2015_1              0.183588        0.197497            0.161335
# 2015_2              0.186111        0.161111            0.163889
# 2015_3              0.202778        0.150000            0.151389
# 2015_4              0.185526        0.160526            0.169737
# 2016_1              0.208333        0.165278            0.175000
# 2016_2              0.195833        0.154167            0.165278
# 2016_3              0.195833        0.170833            0.170833
# 2016_4              0.188158        0.163158            0.156579
# 2017_1              0.180556        0.155556            0.170833
#
#                vader_neg_perc  bert_neg_perc  tfidf_neg_perc  \
# QTR_IDX_SALES
# 2012_2               0.183333       0.165278        0.166667
# 2012_3               0.194444       0.179167        0.191667
# 2012_4               0.197368       0.203947        0.206579
# 2013_1               0.245833       0.212500        0.215278
# 2013_2               0.211405       0.205841        0.208623
# 2013_3               0.256944       0.215278        0.225000
# 2013_4               0.242105       0.225000        0.228947
# 2014_1               0.225000       0.209722        0.230556
# 2014_2               0.241667       0.227778        0.265278
# 2014_3               0.230556       0.233333        0.230556
# 2014_4               0.173684       0.146053        0.192105
# 2015_1               0.235049       0.250348        0.225313
# 2015_2               0.226389       0.211111        0.231944
# 2015_3               0.247222       0.226389        0.238889
# 2015_4               0.242105       0.219737        0.232895
# 2016_1               0.240278       0.223611        0.244444
# 2016_2               0.255556       0.212500        0.236111
# 2016_3               0.225000       0.205556        0.218056
# 2016_4               0.209211       0.207895        0.239474
# 2017_1               0.238889       0.209722        0.209722
#
#                countvect_neg_perc  iphone  ipad
# QTR_IDX_SALES
# 2012_2                   0.152778       0     1
# 2012_3                   0.127778       0     1
# 2012_4                   0.196053       0     1
# 2013_1                   0.165278       0     1
# 2013_2                   0.175243       0     1
# 2013_3                   0.180556       0     1
# 2013_4                   0.198684       0     1
# 2014_1                   0.175000       0     1
# 2014_2                   0.240278       0     1
# 2014_3                   0.186111       0     1
# 2014_4                   0.138158       0     1
# 2015_1                   0.235049       0     1
# 2015_2                   0.184722       0     1
# 2015_3                   0.193056       0     1
# 2015_4                   0.167105       0     1
# 2016_1                   0.193056       0     1
# 2016_2                   0.206944       0     1
# 2016_3                   0.187500       0     1
# 2016_4                   0.190789       0     1
# 2017_1                   0.227778       0     1

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()

print("iPads")
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

plt.subplot(2,1,1)

plt.plot(y_train)
plt.plot(results.predict(X_train))

print("RMSE:", mse(y_train, results.predict(X_train),squared=False))
plt.legend(['Actual Sales', 'Prediction'])


plt.subplot(2,1,2)

plt.plot(y_test)
plt.plot(results.predict(X_test))

print("RMSE:", mse(y_test, results.predict(X_test),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()

results.summary()
# Out:
# iPads
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-1e4131fd6a51> in <module>
#       7 plt.subplot(2,1,1)
#       8
# ----> 9 plt.plot(y_train, kind='x')
#      10 plt.plot(results.predict(X_train))
#      11
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
#     418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 419                 for j in range(max(ncx, ncy))]
#     420
#     421
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
#     418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 419                 for j in range(max(ncx, ncy))]
#     420
#     421
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     388         # update kwargs before updating data to give the caller a
#     389         # chance to init axes (and hence unit support)
# --> 390         self.update(kwargs)
#     391         self.pickradius = pickradius
#     392         self.ind_offset = 0
#
# ~\miniconda3\envs\qntdev\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'kind'

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets[(sales_tweets['ipad']==0) & (sales_tweets['iphone']==0)].set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets[(sales_tweets['ipad']==0) & (sales_tweets['iphone']==0)].set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales','sales_norm'], axis=1), train['sales_norm']
X_test, y_test = test.drop(['sales','sales_norm'], axis=1), test['sales_norm']

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()

print("Macs")
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

plt.subplot(2,1,1)

plt.plot(y_train)
plt.plot(results.predict(X_train))

print("RMSE:", mse(y_train, results.predict(X_train),squared=False))
plt.legend(['Actual Sales', 'Prediction'])


plt.subplot(2,1,2)

plt.plot(y_test)
plt.plot(results.predict(X_test))

print("RMSE:", mse(y_test, results.predict(X_test),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()

results.summary()
# Out:
# Macs
# RMSE: 0.37683600103229664
# RMSE: 5.4669132144751975
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\statsmodels\regression\linear_model.py:1830: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\statsmodels\base\model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# C:\Users\reonh\miniconda3\envs\qntdev\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             sales_norm   R-squared (uncentered):                   0.849
# Model:                            OLS   Adj. R-squared (uncentered):             -0.004
# Method:                 Least Squares   F-statistic:                             0.9959
# Date:                Sun, 28 Mar 2021   Prob (F-statistic):                       0.585
# Time:                        23:01:07   Log-Likelihood:                         -8.8599
# No. Observations:                  20   AIC:                                      51.72
# Df Residuals:                       3   BIC:                                      68.65
# Df Model:                          17
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# replyCount_sum         0.1014      0.140      0.724      0.522      -0.344       0.547
# retweetCount_sum      -0.6569      1.590     -0.413      0.707      -5.716       4.402
# likeCount_sum          0.0697      0.123      0.565      0.611      -0.323       0.462
# quoteCount_sum        -1.7428      2.956     -0.589      0.597     -11.152       7.666
# replyCount_mean      -74.8257    105.178     -0.711      0.528    -409.550     259.898
# retweetCount_mean    475.4191   1141.338      0.417      0.705   -3156.826    4107.664
# likeCount_mean       -49.9304     89.845     -0.556      0.617    -335.857     235.996
# quoteCount_mean     1291.9405   2189.974      0.590      0.597   -5677.535    8261.416
# count                  0.0018      0.033      0.055      0.959      -0.104       0.108
# vader_pos_perc        -9.8572     35.568     -0.277      0.800    -123.051     103.337
# bert_pos_perc          4.5870     35.943      0.128      0.907    -109.798     118.973
# tfidf_pos_perc        27.3076     55.020      0.496      0.654    -147.791     202.407
# countvect_pos_perc   -18.1113     73.790     -0.245      0.822    -252.944     216.721
# vader_neg_perc        15.4277     37.881      0.407      0.711    -105.125     135.981
# bert_neg_perc        -31.2561     25.548     -1.223      0.309    -112.562      50.050
# tfidf_neg_perc        -4.3742     36.855     -0.119      0.913    -121.662     112.913
# countvect_neg_perc    15.8408     26.234      0.604      0.589     -67.646      99.328
# iphone                      0          0        nan        nan           0           0
# ipad                        0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                        0.628   Durbin-Watson:                   2.473
# Prob(Omnibus):                  0.731   Jarque-Bera (JB):                0.022
# Skew:                          -0.002   Prob(JB):                        0.989
# Kurtosis:                       3.161   Cond. No.                          inf
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets[sales_tweets['iphone']==1].set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device'],axis=1)
test = sales_tweets[sales_tweets['iphone']==1].set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device'],axis=1)

X_train, y_train = train.drop(['sales','sales_norm'], axis=1), train['sales_norm']
X_test, y_test = test.drop(['sales','sales_norm'], axis=1), test['sales_norm']

# %%
model = sm.OLS(y_train,X_train)
results = model.fit()

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10,10))

print("iPhone Sales")

plt.subplot(2,1,1)

plt.plot(y_train)
plt.plot(results.predict(X_train))

print("RMSE:", mse(y_train, results.predict(X_train),squared=False))
plt.legend(['Actual Sales', 'Prediction'])


plt.subplot(2,1,2)

plt.plot(y_test)
plt.plot(results.predict(X_test))

print("RMSE:", mse(y_test, results.predict(X_test),squared=False))
plt.legend(['Actual Sales', 'Prediction'])
plt.show()
# Out:
# iPhone Sales
# RMSE: 0.21018473256815037
# RMSE: 14.372307080575853

# %%
sales_tweets.to_csv('sales_tweets.csv')

# %% [markdown]
# ## Add in Text Analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
train = ['2012_1','2012_2', '2012_3', '2012_4', '2013_1', '2013_2', '2013_3',
       '2013_4', '2014_1', '2014_2', '2014_3', '2014_4', '2015_1',
       '2015_2', '2015_3', '2015_4', '2016_1', '2016_2', '2016_3',
       '2016_4']
train = tweets[tweets.QTR_IDX.isin(list(train))]

test = ['2017_1', '2017_2', '2017_3', '2017_4', '2018_1', '2018_2', '2018_3',
       '2018_4']
test = tweets[tweets.QTR_IDX.isin(list(test))]

# %%
traincontent = train.content.apply(lambda x: " ".join([y if not "@" in y else "" for y in x.split(" ")]))
testcontent = test.content.apply(lambda x: " ".join([y if not "@" in y else "" for y in x.split(" ")]))

# %%
vect = TfidfVectorizer(stop_words='english', ngram_range=(1,2),strip_accents='ascii',min_df=0.012)
x_train_dtm = vect.fit_transform(traincontent)
x_test_dtm = vect.transform(testcontent)

# %%
x_train_dtm = pd.DataFrame(x_train_dtm.toarray(), columns = vect.get_feature_names())
x_test_dtm = pd.DataFrame(x_test_dtm.toarray(), columns = vect.get_feature_names())

# %%
x_train_dtm['QTR_IDX'] = train.reset_index()['QTR_IDX']
x_test_dtm['QTR_IDX'] = test.reset_index()['QTR_IDX']

x_train_dtm['device'] = train.reset_index()['device']
x_test_dtm['device'] = test.reset_index()['device']

# %%
tweets_agg_stats
# Out:
#                 replyCount_sum  retweetCount_sum  likeCount_sum  \
# QTR_IDX device
# 2012_1  ipad               406                41             60
#         iphone             376               116             12
#         mac                330                33              8
# 2012_2  ipad               227                43             30
#         iphone             240                77             29
# ...                        ...               ...            ...
# 2018_3  iphone             435               192           3232
#         mac               1200               274           5655
# 2018_4  ipad               300                72           1242
#         iphone             404               166           1978
#         mac                436               517           2444
#
#                 quoteCount_sum  replyCount_mean  retweetCount_mean  \
# QTR_IDX device
# 2012_1  ipad                 0         0.563889           0.056944
#         iphone               0         0.522222           0.161111
#         mac                  0         0.458333           0.045833
# 2012_2  ipad                 0         0.315278           0.059722
#         iphone               0         0.333333           0.106944
# ...                        ...              ...                ...
# 2018_3  iphone              45         0.572368           0.252632
#         mac                 74         1.578947           0.360526
# 2018_4  ipad                24         0.416667           0.100000
#         iphone              31         0.561111           0.230556
#         mac                 42         0.605556           0.718056
#
#                 likeCount_mean  quoteCount_mean
# QTR_IDX device
# 2012_1  ipad          0.083333         0.000000
#         iphone        0.016667         0.000000
#         mac           0.011111         0.000000
# 2012_2  ipad          0.041667         0.000000
#         iphone        0.040278         0.000000
# ...                        ...              ...
# 2018_3  iphone        4.252632         0.059211
#         mac           7.440789         0.097368
# 2018_4  ipad          1.725000         0.033333
#         iphone        2.747222         0.043056
#         mac           3.394444         0.058333
#
# [84 rows x 8 columns]

# %%
x_content = pd.concat([x_train_dtm.groupby(['QTR_IDX', 'device']).sum(), x_test_dtm.groupby(['QTR_IDX', 'device']).sum()])

# %%
x_content = pd.concat([tweets_agg_stats,x_content], axis = 1)

# %%
x_content
# Out:
#                 replyCount_sum  retweetCount_sum  likeCount_sum  \
# QTR_IDX device
# 2012_1  ipad               406                41             60
#         iphone             376               116             12
#         mac                330                33              8
# 2012_2  ipad               227                43             30
#         iphone             240                77             29
# ...                        ...               ...            ...
# 2018_3  iphone             435               192           3232
#         mac               1200               274           5655
# 2018_4  ipad               300                72           1242
#         iphone             404               166           1978
#         mac                436               517           2444
#
#                 quoteCount_sum  replyCount_mean  retweetCount_mean  \
# QTR_IDX device
# 2012_1  ipad                 0         0.563889           0.056944
#         iphone               0         0.522222           0.161111
#         mac                  0         0.458333           0.045833
# 2012_2  ipad                 0         0.315278           0.059722
#         iphone               0         0.333333           0.106944
# ...                        ...              ...                ...
# 2018_3  iphone              45         0.572368           0.252632
#         mac                 74         1.578947           0.360526
# 2018_4  ipad                24         0.416667           0.100000
#         iphone              31         0.561111           0.230556
#         mac                 42         0.605556           0.718056
#
#                 likeCount_mean  quoteCount_mean        air        amp  ...  \
# QTR_IDX device                                                         ...
# 2012_1  ipad          0.083333         0.000000   2.204830   3.089086  ...
#         iphone        0.016667         0.000000   0.000000   3.454605  ...
#         mac           0.011111         0.000000  44.493688   5.623619  ...
# 2012_2  ipad          0.041667         0.000000   0.000000  13.501097  ...
#         iphone        0.040278         0.000000   0.000000  12.888714  ...
# ...                        ...              ...        ...        ...  ...
# 2018_3  iphone        4.252632         0.059211   0.382951   9.169014  ...
#         mac           7.440789         0.097368  31.940552  15.860235  ...
# 2018_4  ipad          1.725000         0.033333   1.635662  14.238325  ...
#         iphone        2.747222         0.043056   0.438425  12.259268  ...
#         mac           3.394444         0.058333  39.638672   7.105868  ...
#
#                     today    twitter        use      using         ve  \
# QTR_IDX device
# 2012_1  ipad     9.693218  17.678506  11.690257   7.904635   4.609313
#         iphone   5.749564  13.920214  10.324906   2.810192   5.269649
#         mac      3.747536   3.846925   8.762068   8.168668  10.618932
# 2012_2  ipad     8.296857  17.341486  17.996750   9.758439   5.640236
#         iphone   5.596263  10.450692   9.016114   4.893779   6.658994
# ...                   ...        ...        ...        ...        ...
# 2018_3  iphone  10.823365   5.665163  13.410329  15.118684   4.103719
#         mac     15.312642   2.303157  27.175285  15.244803   6.356780
# 2018_4  ipad     7.147439   3.606555  32.779506  11.277674  11.369310
#         iphone  10.450239   9.257182   8.866135  10.839512   3.791053
#         mac     12.362694   0.000000  26.532488   8.851819   2.794420
#
#                      want      watch        win       work       year
# QTR_IDX device
# 2012_1  ipad    26.308857   3.814744  13.952529   4.146075   5.507506
#         iphone  15.648133   0.744266   2.068734   3.302761   1.237322
#         mac     19.315352   1.959724  11.160468   4.966880   7.414883
# 2012_2  ipad    18.123629   4.930979  22.430895   9.824442   3.493695
#         iphone  21.774707   2.974102   0.000000   2.265749   0.786925
# ...                   ...        ...        ...        ...        ...
# 2018_3  iphone  18.307885   5.347455   2.507003  11.250140  11.294546
#         mac     20.187048   5.787329   2.263084  18.461698  11.672540
# 2018_4  ipad    17.501748  18.036898   0.607393  13.786661   7.170856
#         iphone  12.630994   6.766218   3.227413   8.605348  10.614190
#         mac     21.694078  10.626690   1.458933  19.512011  12.255227
#
# [84 rows x 70 columns]

# %%
sales_tweets = sales_long.merge(x_content.reset_index(), left_on= ('QTR_IDX_PREV','device'), right_on = ('QTR_IDX','device'))

# %%
sales_tweets['iphone'] = np.where(sales_tweets['device'] == 'iphone',1,0)
sales_tweets['ipad'] = np.where(sales_tweets['device'] == 'ipad',1,0)

# %%
train = sales_tweets.QTR_IDX_SALES.unique()[:20]
test = sales_tweets.QTR_IDX_SALES.unique()[20:]

train = sales_tweets.set_index('QTR_IDX_SALES').loc[train].drop(['QTR_IDX_PREV', 'device','QTR_IDX'],axis=1)
test = sales_tweets.set_index('QTR_IDX_SALES').loc[test].drop(['QTR_IDX_PREV', 'device','QTR_IDX'],axis=1)

X_train, y_train = train.drop('sales', axis=1), train['sales']
X_test, y_test = test.drop('sales', axis=1), test['sales']

# %%
model = sm.OLS(y_train,X_train)

# %%
results = model.fit()
results.summary()
# Out:
# c:\users\reonh\miniconda3\lib\site-packages\statsmodels\regression\linear_model.py:1728: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# c:\users\reonh\miniconda3\lib\site-packages\statsmodels\regression\linear_model.py:1729: RuntimeWarning: invalid value encountered in double_scalars
#   * (1 - self.rsquared))
# c:\users\reonh\miniconda3\lib\site-packages\statsmodels\regression\linear_model.py:1650: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sun, 21 Mar 2021   Prob (F-statistic):                nan
# Time:                        01:20:24   Log-Likelihood:                 1667.6
# No. Observations:                  60   AIC:                            -3215.
# Df Residuals:                       0   BIC:                            -3090.
# Df Model:                          59
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# replyCount_sum        0.0644        inf          0        nan         nan         nan
# retweetCount_sum     -0.0149        inf         -0        nan         nan         nan
# likeCount_sum         0.0010        inf          0        nan         nan         nan
# quoteCount_sum       -0.2246        inf         -0        nan         nan         nan
# replyCount_mean      -0.0007        inf         -0        nan         nan         nan
# retweetCount_mean     0.0060        inf          0        nan         nan         nan
# likeCount_mean        0.0050        inf          0        nan         nan         nan
# quoteCount_mean      -0.0013        inf         -0        nan         nan         nan
# air                  -0.3439        inf         -0        nan         nan         nan
# amp                   0.1744        inf          0        nan         nan         nan
# android               0.7413        inf          0        nan         nan         nan
# app                   0.3665        inf          0        nan         nan         nan
# apple                 0.0786        inf          0        nan         nan         nan
# better               -0.3311        inf         -0        nan         nan         nan
# buy                   0.0603        inf          0        nan         nan         nan
# case                 -0.2090        inf         -0        nan         nan         nan
# charger              -0.1585        inf         -0        nan         nan         nan
# day                   0.2053        inf          0        nan         nan         nan
# did                   0.6920        inf          0        nan         nan         nan
# does                  1.2096        inf          0        nan         nan         nan
# don                   0.2737        inf          0        nan         nan         nan
# finally               0.4280        inf          0        nan         nan         nan
# getting               0.8497        inf          0        nan         nan         nan
# going                 0.5226        inf          0        nan         nan         nan
# good                 -0.4080        inf         -0        nan         nan         nan
# got                   0.5156        inf          0        nan         nan         nan
# got iphone            0.4987        inf          0        nan         nan         nan
# im                   -4.2314        inf         -0        nan         nan         nan
# ipad                 -0.0224        inf         -0        nan         nan         nan
# ipad mini             0.8265        inf          0        nan         nan         nan
# iphone                0.1066        inf          0        nan         nan         nan
# iphone ipad           0.3958        inf          0        nan         nan         nan
# ipod                 -0.7291        inf         -0        nan         nan         nan
# just                  1.0101        inf          0        nan         nan         nan
# know                 -0.8057        inf         -0        nan         nan         nan
# laptop               -0.7098        inf         -0        nan         nan         nan
# life                  2.6706        inf          0        nan         nan         nan
# like                  0.9368        inf          0        nan         nan         nan
# ll                    2.7738        inf          0        nan         nan         nan
# lol                  -0.5025        inf         -0        nan         nan         nan
# love                 -0.3358        inf         -0        nan         nan         nan
# macbook              -0.1233        inf         -0        nan         nan         nan
# macbook air           0.4034        inf          0        nan         nan         nan
# macbook pro           0.3087        inf          0        nan         nan         nan
# make                 -1.7563        inf         -0        nan         nan         nan
# mini                 -0.7968        inf         -0        nan         nan         nan
# need                 -1.2386        inf         -0        nan         nan         nan
# new                  -1.3189        inf         -0        nan         nan         nan
# new iphone           -0.6668        inf         -0        nan         nan         nan
# new macbook           1.1061        inf          0        nan         nan         nan
# old                   0.8802        inf          0        nan         nan         nan
# phone                -0.2777        inf         -0        nan         nan         nan
# pro                  -0.4176        inf         -0        nan         nan         nan
# really               -0.4438        inf         -0        nan         nan         nan
# right                 1.8836        inf          0        nan         nan         nan
# rt                   -0.2186        inf         -0        nan         nan         nan
# screen                0.0536        inf          0        nan         nan         nan
# shit                 -0.4296        inf         -0        nan         nan         nan
# think                 0.9833        inf          0        nan         nan         nan
# time                 -0.9647        inf         -0        nan         nan         nan
# today                -0.6266        inf         -0        nan         nan         nan
# twitter               0.7160        inf          0        nan         nan         nan
# use                  -0.5010        inf         -0        nan         nan         nan
# using                -0.4228        inf         -0        nan         nan         nan
# ve                    0.3744        inf          0        nan         nan         nan
# want                  0.8553        inf          0        nan         nan         nan
# watch                -1.9664        inf         -0        nan         nan         nan
# win                   0.0251        inf          0        nan         nan         nan
# work                  1.0892        inf          0        nan         nan         nan
# year                 -0.1869        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        0.067   Durbin-Watson:                   1.589
# Prob(Omnibus):                  0.967   Jarque-Bera (JB):                0.243
# Skew:                           0.045   Prob(JB):                        0.886
# Kurtosis:                       2.702   Cond. No.                     3.77e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The condition number is large, 3.77e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn.metrics import mean_squared_error as mse

mse(y_test, results.predict(X_test),squared=False)
# Out:
# 80.36309710404927
